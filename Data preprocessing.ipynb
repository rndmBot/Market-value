# %%
import pandas as pd
import numpy as np
import re
import os
import time
import translitua

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Raw data

# %%
# Loading raw data
df = pd.read_csv('ria_raw.csv', encoding = 'windows-1251')

print(df.shape) # Rows, cols
df.head()
# Out:
# (261855, 4)
#                                                parse  \
# 0  /ru/realty-perevireno-prodaja-kvartira-kiev-so...
# 1  /ru/realty-perevireno-prodaja-kvartira-kiev-so...
# 2  /ru/realty-perevireno-prodaja-dom-vinnitsa-yak...
# 3  /ru/realty-perevireno-prodaja-kvartira-vinnits...
# 4  /ru/realty-perevireno-prodaja-kvartira-vinnits...
#
#                                               parse2 price_usd  \
# 0     р-н. Соломенский ул. Ереванская 1 ком. г. Киев  71 970 $
# 1  р-н. Соломенский Машинобудівна вулиця 1 ком. г...  68 000 $
# 2  р-н. Якушинцы ул. Богдана Хмельницкого 134м кв...  53 000 $
# 3  р-н. Свердловский массив ул. Матроса Кошки 1 к...  36 500 $
# 4        р-н. Стрижавка Алеи улица 1 ком. г. Винница  16 582 $
#
#                  parse3
# 0     1 комната 57 м кв
# 1     1 комната 68 м кв
# 2      134 м кв 7 соток
# 3     1 комната 36 м кв
# 4  1 комната 40.24 м кв

# %%
# Null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261855 entries, 0 to 261854
# Data columns (total 4 columns):
# parse        261855 non-null object
# parse2       261855 non-null object
# price_usd    260053 non-null object
# parse3       247766 non-null object
# dtypes: object(4)
# memory usage: 8.0+ MB

# %% [markdown]
# ### Removing null values

# %%
df.dropna(subset = ['price_usd'], inplace = True)
print(df.shape)
df.head()
# Out:
# (260053, 4)
#                                                parse  \
# 0  /ru/realty-perevireno-prodaja-kvartira-kiev-so...
# 1  /ru/realty-perevireno-prodaja-kvartira-kiev-so...
# 2  /ru/realty-perevireno-prodaja-dom-vinnitsa-yak...
# 3  /ru/realty-perevireno-prodaja-kvartira-vinnits...
# 4  /ru/realty-perevireno-prodaja-kvartira-vinnits...
#
#                                               parse2 price_usd  \
# 0     р-н. Соломенский ул. Ереванская 1 ком. г. Киев  71 970 $
# 1  р-н. Соломенский Машинобудівна вулиця 1 ком. г...  68 000 $
# 2  р-н. Якушинцы ул. Богдана Хмельницкого 134м кв...  53 000 $
# 3  р-н. Свердловский массив ул. Матроса Кошки 1 к...  36 500 $
# 4        р-н. Стрижавка Алеи улица 1 ком. г. Винница  16 582 $
#
#                  parse3
# 0     1 комната 57 м кв
# 1     1 комната 68 м кв
# 2      134 м кв 7 соток
# 3     1 комната 36 м кв
# 4  1 комната 40.24 м кв

# %% [markdown]
# ### "Parse" column preprocessing

# %%
# Extracting offer type
df['parse'] = df['parse'].apply(lambda x: x.replace('_', '-'))
df['parse'] = df['parse'].apply(lambda x: x.replace('perevireno-', '').replace('/ru/realty-', ''))
df['parse'] = df['parse'].apply(lambda x: x.replace('prodaja', 'prodaj').replace('prodaj', 'sell/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('dolgosrochnaya-arenda', 'lt_rent/').replace('dovgostrokova-orenda', 'lt_rent/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('arenda-posutochnaya', 'st_rent/').replace('orenda-podobova', 'st_rent/'))

df['offer_type'] = df['parse'].apply(lambda x: x.split('/')[0])
df['parse'] = df['parse'].apply(lambda x: x.split('/-')[1])

# Extracting type of real estate
df['parse'] = df['parse'].apply(lambda x: x.replace('kvartira-', 'apartments/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('dom-', 'house/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('budinok-', 'house/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('pomescheniya-svobodnogo-naznacheniya-', 'PSN/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('ofisnyie-pomescheniya-', 'office/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('ofisnye-pomescheniya-', 'office/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('ofisnoe-pomeschenie-', 'office/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('skladskie-pomescheniya-', 'warehouse/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('proizvodstvennye-pomescheniya-', 'industrial/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('proizvodstvennyie-pomescheniya-', 'industrial/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('uchastok-pod-jiluyu-zastroyku-', 'land/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('chast-doma-', 'part_of_house/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('zemlya-kommercheskogo-naznacheniya-', 'land/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('zemlya-selskohozyaystvennogo-naznacheniya-', 'land/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('komnata-', 'room/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('torgovyie-ploschadi-', 'commercial_area/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('torgovye-ploschadi-', 'commercial_area/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('obyekt-sferyi-uslug-', 'services/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('obyekt-sfery-uslug-', 'services/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('dacha', 'country_house/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('boks-v-garajnom-komplekse-', 'garage/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('otdelno-stoyaschiy-garaj-', 'garage/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('mesto-v-garajnom-kooperative-', 'parking_space/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('podzemnyiy-parking-', 'parking_space/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('podzemnyy-parking-', 'parking_space/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('mesto-na-stoyanke-', 'parking_space/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('ofisnyie-zdaniya-', 'office_complex/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('ofisnye-zdaniya-', 'office_complex/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('ofisnoe-zdanie-', 'office_complex/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('otel-gostinitsa-', 'hotel/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('kafe-bar-restoran-', 'recreational/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('baza-otdyha-pansionat-', 'recreational/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('baza-otdyiha-pansionat-', 'recreational/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('gotovyy-biznes-', 'business/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('gotovyiy-biznes-', 'business/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('zemlya-rekreatsionnogo-naznacheniya-', 'land/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('zemlya-prirodnozapovednogo-naznacheniya-', 'land/'))
df['parse'] = df['parse'].apply(lambda x: x.replace('zemlya-prirodno-zapovednogo-naznacheniya-', 'land/'))

df['type'] = df['parse'].apply(lambda x: x.split('/')[0])

# Drop 'parse' column
df.drop('parse', axis = 1, inplace = True)

# %%
# Data after "parse" column preprocessing
df.head()
# Out:
#                                               parse2 price_usd  \
# 0     р-н. Соломенский ул. Ереванская 1 ком. г. Киев  71 970 $
# 1  р-н. Соломенский Машинобудівна вулиця 1 ком. г...  68 000 $
# 2  р-н. Якушинцы ул. Богдана Хмельницкого 134м кв...  53 000 $
# 3  р-н. Свердловский массив ул. Матроса Кошки 1 к...  36 500 $
# 4        р-н. Стрижавка Алеи улица 1 ком. г. Винница  16 582 $
#
#                  parse3 offer_type        type
# 0     1 комната 57 м кв       sell  apartments
# 1     1 комната 68 м кв       sell  apartments
# 2      134 м кв 7 соток       sell       house
# 3     1 комната 36 м кв       sell  apartments
# 4  1 комната 40.24 м кв       sell  apartments

# %% [markdown]
# ### "Parse2" column preprocessing

# %%
# Extracting city names
df['city'] = df['parse2'].apply(lambda x: re.findall(r'г\.\s\w+', x)[-1].replace('г. ', ''))

cities = {
'Івано': 'Ивано Франковск', 'Голая': 'Голая Пристань', 'Каменец': 'Каменец-Подольский', 'Новая': 'Новая Каховка',
'Berezan': 'Березань', 'Burshtyn': 'Бурштын',
'Gnivan': 'Гнивань', 'Lubotun': 'Люботин', 'Noviy': 'Новый роздол', 'Uzhgorod': 'Ужгород', 'rzishev': 'Ржев', 'Іршавa': 'Иршава',
'Белая': 'Белая Церковь', 'Бердичів': 'Бердичев', 'Богородчани': 'Богородчани', 'Бориспіль': 'Борисполь', 'Борщів': 'Борщев', 'Буськ': 'Буск', 'Бучач': 'Буча',
'Гола': 'Голая Пристань', 'Залізний': 'Железный порт', 'Киево': 'Киево-Святошинский', 'Кривой': 'Кривой рог', 
'Малая': 'Малая Виска', 'Нова': 'Нова Ушиця', 'Новий': 'Новий Роздол', 'Новые': 'Новые Санжары', 'Новый': 'Новый Буг',
'Овідіополь': 'Овидиополь', 'Одеса': 'Одесса', 'Оржиця': 'Оржица', 'П': 'Пятихатки', 'Старая': 'Старая Синява', 'Старий': 'Старый Самбор', 'Старый': 'Старый Самбор', 
'Ивано': 'Івано-Франківськ', 'Ильичевск': 'Чорноморськ', 'Литин': 'Літин', 'Соленое': 'Солоне', 'Межгорье': "Міжгір'я",
'Александрия': 'Олександрія', 'Чертков': 'Чортків', 'Раздельная': 'Роздільна', 'Красный': 'Хрустальный', 'Белгород': 'Білгород-Дністровський',
'Гребенка': 'Гребінка', 'Бобровица': 'Бобровиця', 'Первомайск': 'Первомайськ', 'Котовск': 'Подільськ', 'Орехов': 'Оріхів',
'Комсомольск': 'Горішні Плавні', 'Зборов': 'Зборів', 'Приморск': 'Приморськ', 'Великая': 'Велика Новосілка',
'Шацк': 'Шацьк', 'Васильковка': 'Васильківка', 'Семеновка': 'Семенівка', 'Ширяево': 'Ширяєве', 'Чутово': 'Чутове',
'Александровка': 'Олександрівка', 'Петрово': 'Петрове', 'Середина': 'Середина-Буда', 'Новгород': 'Новгород-Сіверський',
'Красноармейск': 'Покровськ', 'Дзержинск': 'Торецьк', 'Снигиревка': 'Снігурівка', 'Кривое': 'Кривий Ріг', 'Карловка': 'Карлівка',
'Куйбышево': 'Більмак', 'Михайловка': 'Михайлівка',    
}

df['city'] = df['city'].replace(cities)

# Drop 'parse2' column
df.drop('parse2', axis = 1, inplace = True)

# %% [markdown]
# ### Region column creation

# %%
# Nominatim instance for geocoding
geo = Nominatim(user_agent = 'thesis_donnu', timeout = 3)

# Dict to store region address
regions = dict()

for city in df['city'].unique():
    try:
        location = geo.geocode(city)
        print(location.address)
        regions[city] = location.address
    except:
        print(city, ' ERROR')
    time.sleep(1)
# Out:
# Київ, Шевченківський район, Київ, 1001, Україна
# Вінниця, Вінницька область, 21000-21499, Україна
# Одеса, Приморський район, Одеса, Одеська область, 65026, Україна
# Львів, Галицький район, Львівська міська рада, Львівська область, Україна
# Дніпро, Шевченківський район, Дніпровська міська рада, Дніпропетровська область, Україна
# Ужгород, Закарпатська область, 88000-88499, Україна
# Буча, Київська область, 08293, Україна
# Харків, Шевченківський район, Харківська міська рада, Харківська область, Україна
# Києво-Святошинський район, Київська область, Україна
# Миколаїв, Центральний район, Миколаївська міська рада, Миколаївська область, Україна
# Тернопіль, Тернопільська область, 46000-46499, Україна
# Вишгород, Вишгородський район, Київська область, 07301, Україна
# Хмельницький, Хмельницька область, 29000-29499, Україна
# Запоріжжя, Вознесенівський район, Запорізька міська рада, Запорізька область, 69000-69499, Україна
# Івано-Франківськ, Івано-Франківська міська рада, Івано-Франківська область, Україна
# Черкаси, Соснівський район, Черкаська міська рада, Черкаська область, 18000-18499, Україна
# Ірпінь, Ірпінська міська рада, Київська область, Україна
# Рівне, Рівненська область, 33000-33499, Україна
# Чорноморськ, Чорноморська міська рада, Одеська область, Україна
# Луцьк, Луцька міська рада, Волинська область, Україна
# Бориспіль, Київська область, 08300-08307, Україна
# Житомир, Житомирська міська територіальна громада, Житомирська область, 10000-10499, Україна
# Овідіополь, Овідіопольська селищна рада, Овідіопольський район, Одеська область, 67800-67805, Україна
# Полтава, Полтавська область, Україна
# Липовець, Липовецька міська рада, Липовецький район, Вінницька область, 22500-22505, Україна
# Херсон, Суворовський район, Херсонська міська рада, Херсонська область, Україна
# Пустомити, Пустомитівська міська рада, Пустомитівський район, Львівська область, 81100, Україна
# Тисмениця, Тисменицький район, Івано-Франківська область, Україна
# Обухів, Обухівська міська рада, Київська область, Україна
# Доброслав, Лиманський район, Одеська область, 67500, Україна
# Біла Церква, Київська область, 09100-09117, Україна
# Хмільник, Вінницька область, 22000, Україна
# Чернівці, Чернівецька область, 58000-58033, Україна
# Тиврів, Тиврівський район, Вінницька область, 23300, Україна
# Літин, Літинський район, Вінницька область, 22300, Україна
# Бровари, Київська область, 07400, Україна
# Макарів, Макарівський район, Київська область, 08000, Україна
# Дергачі, Дергачівський район, Харківська область, Україна
# Зміїв, Зміївський район, Харківська область, Україна
# Тернопіль, Тернопільська область, 46000-46499, Україна
# Здолбунів, Здолбунівський район, Рівненська область, Україна
# Калинівка, Калинівський район, Вінницька область, Україна
# Коростишів, Коростишівська міська рада, Коростишівська міська об'єднана територіальна громада, Коростишівський район, Житомирська область, Україна
# Немирів, Немирівський район, Вінницька область, Україна
# Сторожинець, Сторожинецький район, Чернівецька область, Україна
# Олешки, Олешківський район, Херсонська область, Україна
# Чугуїв, Чугуївська міська рада, Харківська область, Україна
# Жмеринка, Вінницька область, 23100-23107, Україна
# Яворів, Яворівський район, Львівська область, 81000, Україна
# Затока, Білгород-Дністровська міська рада, Одеська область, 67776, Україна
# Печеніги, Рибна вулиця, Печеніги, Печенізький район, Харківська область, 62801, Україна
# Новомосковськ, Дніпропетровська область, 51200-51214, Україна
# Кіцмань, Кіцманський район, Чернівецька область, Україна
# Ківерці, Ківерцівський район, Волинська область, Україна
# Івано-Франківськ, Івано-Франківська міська рада, Івано-Франківська область, Україна
# Ярмолинці, Ярмолинецький район, Хмельницька область, 32100, Україна
# Васильків, Київська область, 08600-08606, Україна
# Солоне, Солонянський район, Дніпропетровська область, 52400-52404, Україна
# Бородянка, Бородянський район, Київська область, 07800-07805, Україна
# Хмельницький, Хмельницька область, 29000-29499, Україна
# Перемишляни, Перемишлянський район, Львівська область, 81200, Україна
# Біляївка, Біляївська міська рада, Одеська область, Україна
# Виноградів, Виноградівський район, Закарпатська область, 90300, Україна
# Стрий, Стрийська міська рада, Львівська область, Україна
# Чернігів, Деснянський район, Чернігівська міська рада, Чернігівська область, 14000-14499, Україна
# Свалява, Головна вулиця, Свалявська міська рада, Свалявський район, Закарпатська область, 89300, Україна
# Владимир, городской округ Владимир, Владимирская область, Центральный федеральный округ, 600000, Россия
# Гола Пристань, Голопристанська міська рада, Херсонська область, 75600, Україна
# Старокостянтинів, Старокостянтинівська міська рада, Хмельницька область, Україна
# Міжгір’я, Міжгірський район, Закарпатська область, 90000-90004, Україна
# Підволочиськ, Підволочиський район, Тернопільська область, 47800, Україна
# Збараж, Збаразький район, Тернопільська область, 47300-47304, Україна
# Дрогобич, Дрогобицька міська рада, Львівська область, Україна
# Трускавець, Трускавецька міська рада, Львівська область, 82200, Україна
# Миронівка, Миронівська міська рада, Миронівський район, Київська область, Україна
# Никопол, Плевен, 5940, България
# Броди, Бродівська міська рада, Бродівський район, Львівська область, 80600-80603, Україна
# Носівка, Носівський район, Чернігівська область, Україна
# Яготин, Яготинський район, Київська область, Україна
# Буськ, Буський район, Львівська область, 80500, Україна
# Косів, Косівський район, Івано-Франківська область, Україна
# Кам’янець-Подільський, Хмельницька область, 32300-32315, Україна
# Крижопіль, Крижопільський район, Вінницька область, 24601, Україна
# Кропивницький, Подільський район, Кіровоградська міська рада, Кіровоградська область, 25000-25490, Україна
# Жашків, Жашківський район, Черкаська область, Україна
# Кривий Ріг, Саксаганський район, Кривий Ріг, Дніпропетровська область, 50000-50479, Україна
# Мукачево, Закарпатська область, 89600, Україна
# Barr, Sélestat-Erstein, Bas-Rhin, Grand Est, France métropolitaine, 67140, France
# Тараща, Таращанський район, Київська область, Україна
# Куп’янськ, Куп’янська міська рада, Харківська область, Україна
# Берегове, Берегівська міська рада, Закарпатська область, Україна
# Бердянськ, Бердянська міська рада, Запорізька область, Україна
# Хуст, Хустська міська рада, Закарпатська область, Україна
# Переяслав, Київська область, 08400-08409, Україна
# Горохів, Горохівський район, Волинська область, Україна
# Коломия, Івано-Франківська область, 78200, Україна
# Верховина, Верховинський район, Івано-Франківська область, 78700, Україна
# Гайсин, Гайсинський район, Вінницька область, Україна
# Скадовськ, Скадовський район, Херсонська область, Україна
# Синельникове, Дніпропетровська область, 52500-52507, Україна
# Радомишль, Радомишльська міська рада, Радомишльська міська об’єднана територіальна громада, Радомишльський район, Житомирська область, Україна
# Тетіїв, Тетіївський район, Київська область, 09804, Україна
# Тячів, Тячівський район, Закарпатська область, 90500, Україна
# Яремча, 264, Свободи вулиця, Ямна, Яремче, Яремчанська міська рада, Івано-Франківська область, 78501, Україна
# Корсунь, Єнакієвська міська рада, Донецька область, 86499, Україна
# Кам’янське, Заводський район, Камʼянська міська рада, Дніпропетровська область, Україна
# Новоселиця, Старокостянтинівський район, Хмельницька область, 31162, Україна
# Сарни, Сарненський район, Рівненська область, Україна
# Слов’янськ, Слов’янська міська рада, Донецька область, 84100-84129, Україна
# Городок, Городоцький район, Львівська область, 81504, Україна
# Маріуполь, Центральний район, Маріупольська міська рада, Донецька область, 87500-87590, Україна
# Суми, Зарічний район, Сумська міська рада, Сумська область, 40000-40489, Україна
# Сквира, Сквирський район, Київська область, 09000-09003, Україна
# Заліщики, Заліщицька міська рада, Заліщицький район, Тернопільська область, Україна
# Стрий, Стрийська міська рада, Львівська область, Україна
# Краматорськ, Краматорська міська рада, Донецька область, 84300-84390, Україна
# Самбір, Самбірська міська рада, Львівська область, 81400, Україна
# Кагарлик, Кагарлицький район, Київська область, Україна
# Нововолинськ, Нововолинська міська рада, Волинська область, Україна
# Лозова, Лозівська міська рада, Харківська область, Україна
# Олександрія, Олександрійська міська рада, Кіровоградська область, Україна
# Чортків, Тернопільська область, 48500-48509, Україна
# Роздільна, Роздільнянський район, Одеська область, Україна
# Дубровиця, Дубровицький район, Рівненська область, Україна
# Черкаси, Соснівський район, Черкаська міська рада, Черкаська область, 18000-18499, Україна
# Могилев, Боровской сельсовет, Болотнинский район, Новосибирская область, Сибирский федеральный округ, Россия
# Ковель, Ковельська міська рада, Волинська область, Україна
# Хрустальний, Краснолуцька міська рада, Луганська область, Україна
# Баришівка, Баришівський район, Київська область, 07500-07571, Україна
# Міжгір  ERROR
# Борщів, Борщівська міська рада, Борщівський район, Тернопільська область, 48700, Україна
# Калуш, Калуська міська рада, Івано-Франківська область, Україна
# Млынов  ERROR
# Теребовля, Теребовлянська міська рада, Теребовлянський район, Тернопільська область, 48100, Україна
# Надвірна, Надвірнянський район, Івано-Франківська область, Україна
# Шпола, Шполянський район, Черкаська область, Україна
# Нова Каховка, Новокаховська міська рада, Херсонська область, Україна
# Горохів, Горохівський район, Волинська область, Україна
# Білгород-Дністровський, Білгород-Дністровська міська рада, Одеська область, 67700-67719, Україна
# Генічеськ, Генічеський район, Херсонська область, Україна
# Кролевець, Кролевецька міська об’єднана територіальна громада, Кролевецький район, Сумська область, 41300-41305, Україна
# Кременчук, Автозаводський район, Кременчуцька міська рада, Полтавська область, 39600-39689, Україна
# Ізмаїл, Одеська область, 68600-68633, Україна
# Миргород, Малоліщанська вулиця, Харківка, Миргород, Миргородська міська рада, Полтавська область, 37600, Україна
# Гребінка, Гребінківський район, Полтавська область, 37400, Україна
# Балаклія, Балаклійський район, Харківська область, Україна
# Ямпіль, Білогірський район, Хмельницька область, 30231, Україна
# Новоград-Волинський, Новоград-Волинська міська рада, Новоград-Волинська міська об'єднана територіальна громада, Житомирська область, Україна
# Бобровиця, Бобровицький район, Чернігівська область, 17400, Україна
# Ватутіне, Ватутінська міська рада, Черкаська область, 20250, Україна
# Вовчанськ, Вовчанський район, Харківська область, Україна
# Долина, Долинський район, Івано-Франківська область, Україна
# Ніжин, Ніжинська міська рада, Чернігівська область, 16600, Україна
# Монастириська, Монастириський район, Тернопільська область, 48300-48305, Україна
# Деражня, Деражнянський район, Хмельницька область, Україна
# Кременець, Кременецька міська рада, Тернопільська область, Україна
# Красилів, Красилівський район, Хмельницька область, Україна
# Фастів, Київська область, 08500-08509, Україна
# Жовква, Жовківський район, Львівська область, 80300, Україна
# Київ, Шевченківський район, Київ, 1001, Україна
# Первомайск, городской округ Первомайск, Нижегородская область, Приволжский федеральный округ, Россия
# Теофіполь, Теофіпольський район, Хмельницька область, 30600-30608, Україна
# Гнівань, Тиврівський район, Вінницька область, Україна
# Монастирище, Монастирищенський район, Черкаська область, 19100-19109, Україна
# Теплодар, Одеська область, Україна
# Радивилів, Радивилівський район, Рівненська область, 35500-35508, Україна
# Буковель, Яремчанська міська рада, Івано-Франківська область, 78593, Україна
# Богородчани, Богородчанський район, Івано-Франківська область, Україна
# Бершадь, Бершадський район, Вінницька область, Україна
# Бережани, Бережанська міська рада, Тернопільська область, Україна
# Люботин, Люботинська міська рада, Харківська область, 62433, Україна
# Козятин, Козятинський район, Вінницька область, 22109, Україна
# Козелець, Козелецький район, Чернігівська область, Україна
# Mina, Nuevo León, México
# Подільськ, Одеська область, 66314, Україна
# Котовск, городской округ Котовск, Тамбовская область, Центральный федеральный округ, Россия
# Сколе, Сколівська міська рада, Сколівський район, Львівська область, Україна
# Червоноград, Червоноградська міська рада, Львівська область, Україна
# Бурштин, Бурштинська міська рада, Івано-Франківська область, 77111, Україна
# Котельва, Котелевський район, Полтавська область, Україна
# Мостиська, Мостиська міська рада, Мостиський район, Львівська область, Україна
# Костопіль, Костопільський район, Рівненська область, Україна
# Старий Самбір, Старосамбірська міська рада, Старосамбірський район, Львівська область, 82000, Україна
# Рубіжне, Рубіжанська міська рада, Луганська область, Україна
# Приазовське, Приазовський район, Запорізька область, Україна
# Чорнухи, Чорнухинський район, Полтавська область, 37101, Україна
# Драбів, Драбівська селищна рада, Драбівська селищна громада, Драбівський район, Черкаська область, 19800-19805, Україна
# Миколаївка, Миколаївська селищна об’єднана територіальна громада, Білопільський район, Сумська область, 41854, Україна
# Покров, Покровська міська рада, Дніпропетровська область, 53300-53390, Україна
# Царичанка, Царичанський район, Дніпропетровська область, Україна
# Золотоноша, Золотоніська міська рада, Черкаська область, 19700-19705, Україна
# Оріхів, Оріхівський район, Запорізька область, 70500-70504, Україна
# Іванівка, Антрацитівський район, Луганська область, 94644, Україна
# Гусятин, Гусятинський район, Тернопільська область, Україна
# Борзна, Борзнянський район, Чернігівська область, Україна
# عمان
# Томаківка, Томаківський район, Дніпропетровська область, 53500-53504, Україна
# Жидачів, Жидачівська міська рада, Жидачівський район, Львівська область, 81700, Україна
# Іванків, Іванківський район, Київська область, 07200, Україна
# Коблеве, Березанський район, Миколаївська область, Україна
# Летичів, Летичівський район, Хмельницька область, 31500, Україна
# Мелітополь, Запорізька область, 72300-72324, Україна
# Бахмут 2, Чайковського провулок, Бахмут, Бахмутська міська рада, Донецька область, 84500-84510, Україна
# Пологи, Пологівський район, Запорізька область, 70600-70614, Україна
# Сміла, Смілянська міська рада, Черкаська область, Україна
# Попільня, Попільнянський район, Житомирська область, 13500-13503, Україна
# Южноукраїнськ, Южноукраїнська міська рада, Миколаївська область, Україна
# Глобине, Глобинський район, Полтавська область, Україна
# Сєвєродонецьк, Сєвєродонецька міська рада, Луганська область, Україна
# Ромни, Роменська міська рада, Сумська область, Україна
# Карло-Марксове, Єнакієвська міська рада, Донецька область, 86485-86486, Україна
# Добропілля, Добропільська міська рада, Донецька область, 85000-85009, Україна
# Канів, Черкаська область, 19000-19009, Україна
# Золочів, Золочівський район, Харківська область, Україна
# Іршава, Іршавський район, Закарпатська область, 90100, Україна
# Вижниця, Вижницький район, Чернівецька область, 59200, Україна
# Погребище, Погребищенський район, Вінницька область, Україна
# Козова, Козівський район, Тернопільська область, 47600, Україна
# Дубляни, Дублянська міська рада, Жовківський район, Львівська область, 80381, Україна
# Брусилів, Брусилівська селищна об'єднана територіальна громада, Брусилівський район, Житомирська область, 12605, Україна
# Андрушівка, Андрушівський район, Житомирська область, Україна
# Рожище, Рожищенський район, Волинська область, Україна
# Шаргород, Шаргородський район, Вінницька область, 23500-23504, Україна
# Звенигородка, Звенигородська міська рада, Звенигородський район, Черкаська область, Україна
# Вінниця, Вінницька область, 21000-21499, Україна
# Кельменці, Кельменецький район, Чернівецька область, Україна
# Краснокутськ, Краснокутський район, Харківська область, 62000-62002, Україна
# Очаків, Миколаївська область, 57500, Україна
# Южне, Одеська область, 65481-65489, Україна
# Згурівка, Згурівський район, Київська область, Україна
# Рожнятів, Рожнятівський район, Івано-Франківська область, 77600, Україна
# Пулини, Пулинський район, Житомирська область, 12004, Україна
# Великий, Павловское сельское поселение, Вилегодский район, Архангельская область, Северо-Западный федеральный округ, Россия
# Бердичів, Житомирська область, Україна
# Красноград  ERROR
# Чуднів, Чуднівська міська рада, Чуднівський район, Житомирська область, 13200, Україна
# Березівка, Березівський район, Одеська область, Україна
# Sărata, Sibiu, 557193, România
# Кобеляки, Кобеляцький район, Полтавська область, Україна
# Васильевка  ERROR
# Славута  ERROR
# Полонное  ERROR
# Кегичівка, Кегичівський район, Харківська область, 64003, Україна
# Сокиряни, Сокирянський район, Чернівецька область, 60200-60207, Україна
# Тростянець, Тростянецька міська об’єднана територіальна громада, Тростянецький район, Сумська область, 42600-42615, Україна
# Дубно, Рівненська область, 35600-35608, Україна
# Троїцьке, Троїцький район, Луганська область, 92102, Україна
# Ставище, Ставищенський район, Київська область, 09400, Україна
# Коломия, Івано-Франківська область, 78200, Україна
# Березанка, Березанський район, Миколаївська область, 57400-57409, Україна
# Баштанка, Баштанський район, Миколаївська область, 56100-56109, Україна
# Галич, Галицький район, Івано-Франківська область, 77100, Україна
# Березне, Березнівський район, Рівненська область, Україна
# Білозерка, Білозерський район, Херсонська область, Україна
# Конотоп, Конотопська міська об’єднана територіальна громада, Конотопська міська рада, Сумська область, 41600-41615, Україна
# Каланчак, Каланчацький район, Херсонська область, Україна
# Каменка, Каменский район, Пензенская область, Приволжский федеральный округ, Россия
# Рокитне, Рокитнянський район, Київська область, 09600, Україна
# Теплик, Теплицький район, Вінницька область, 23800, Україна
# Горішні Плавні, Горішньоплавнівська міська рада, Полтавська область, Україна
# Новий Розділ, Новороздільська міська рада, Львівська область, 81652, Україна
# Вознесенськ, Миколаївська область, 56500-56518, Україна
# Волочиськ, Волочиський район, Хмельницька область, Україна
# Моршин, Моршинська міська рада, Львівська область, 82482, Україна
# Дунаївці, Дунаєвецький район, Хмельницька область, Україна
# Зборів, Зборівський район, Тернопільська область, 47201, Україна
# Радехів, Радехівський район, Львівська область, 80200, Україна
# Магдалинівка, Магдалинівський район, Дніпропетровська область, 51100-51104, Україна
# Гоща, М-06, Гоща, Гощанський район, Рівненська область, 35400, Україна
# Прилуки, Чернігівська область, 17500-17511, Україна
# Острог, Рівненська область, 35800-35807, Україна
# Каховка, Каховська міська рада, Херсонська область, 74800, Україна
# Железный, Беренжакский сельсовет, Ширинский район, Республика Хакасия, Сибирский федеральный округ, Россия
# Снятин, Снятинський район, Івано-Франківська область, Україна
# Кілія, Кілійський район, Одеська область, 68300-68303, Україна
# Перечин, Перечинський район, Закарпатська область, Україна
# Чорнобай, Чорнобаївський район, Черкаська область, 19900, Україна
# Лебедин, Лебединська міська рада, Сумська область, Україна
# Турка, Турківська міська рада, Турківський район, Львівська область, 82500, Україна
# Решетилівка, Полтавська область, 38400, Україна
# Мангуш, Мангушська селищна рада, Мангушський район, Донецька область, 87400-87405, Україна
# Саврань, Савранський район, Одеська область, 66200, Україна
# Христинівка, Христинівський район, Черкаська область, 20000-20008, Україна
# Kamień, gmina Mirsk, powiat lwówecki, województwo dolnośląskie, Polska
# Миколаїв, Центральний район, Миколаївська міська рада, Миколаївська область, Україна
# Малин, Малинcька міська рада, Житомирська область, Україна
# Лубни, Лубенська міська рада, Полтавська область, Україна
# Приморск, Выборгский район, Ленинградская область, Северо-Западный федеральный округ, 188910, Россия
# Ріпки, Ріпкинський район, Чернігівська область, 15000, Україна
# Гадяч, Гадяцька міська рада, Полтавська область, 37300-37305, Україна
# Шостка, Шосткинська міська об’єднана територіальна громада, Шосткинська міська рада, Сумська область, Україна
# Романів, Романівський район, Житомирська область, 13001, Україна
# Першотравенськ, Дніпропетровська область, Україна
# Марганець, Марганецька міська рада, Дніпропетровська область, Україна
# Якимівка, Якимівський район, Запорізька область, 72500-72504, Україна
# Новопсков, Новопсковський район, Луганська область, 92309, Україна
# Павлоград, Дніпропетровська область, 51400-51429, Україна
# Кринички, Криничанський район, Дніпропетровська область, 52300-52305, Україна
# Верхньодніпровськ, Верхньодніпровський район, Дніпропетровська область, 51600, Україна
# Чоп, Закарпатська область, 89500, Україна
# Городищи, Петушинский район, Владимирская область, Центральный федеральный округ, Россия
# Чигирин, Чигиринський район, Черкаська область, 20900-20906, Україна
# Татарбунари, Татарбунарський район, Одеська область, 68100-68104, Україна
# Борислав, Бориславська міська рада, Львівська область, Україна
# Ладижин, Ладижинська міська рада, Вінницька область, Україна
# Лисичанськ, Лисичанська міська рада, Луганська область, 93100, Україна
# Чемерівці, Чемеровецький район, Хмельницька область, 31600, Україна
# Благовіщенське, Благовіщенський район, Кіровоградська область, 26400, Україна
# Велика Новосілка, Великоновосілківський район, Донецька область, 85500, Україна
# Вільнянськ, Вільнянський район, Запорізька область, Україна
# Тальне, Тальнівський район, Черкаська область, Україна
# Муроване, Старосамбірський район, Львівська область, 82055, Україна
# Шацк, Шацкий район, Рязанская область, Центральный федеральный округ, 391550, Россия
# Хотин, Хотинський район, Чернівецька область, 60000-60005, Україна
# Костянтинівка, Костянтинівcька мiська рада, Донецька область, 85100-85129, Україна
# Гуляйполе, Шевченка вулиця, Богданівка, Підволочиський район, Тернопільська область, 47832, Україна
# Луцьк, Луцька міська рада, Волинська область, Україна
# Онуфріївка, Онуфріївський район, Кіровоградська область, 28100, Україна
# Петриківка, Петриківський район, Дніпропетровська область, 51800-51804, Україна
# Хорол, Хорольський район, Полтавська область, 37800, Україна
# Арциз, Арцизький район, Одеська область, Україна
# Корець, Корецький район, Рівненська область, Україна
# Богуслав, Богуславський район, Київська область, 09701, Україна
# Сокаль, Сокальський район, Львівська область, 80005, Україна
# Любомль, Любомльський район, Волинська область, Україна
# Коростень, Коростенська міська рада, Житомирська область, Україна
# Рахів, Рахівський район, Закарпатська область, 90600, Україна
# Васильківка, Васильківський район, Дніпропетровська область, 52600-52604, Україна
# Більмак, Куйбишевська селищна рада, Більмацький район, Запорізька область, 71000-71004, Україна
# Сновськ, Сновська міська рада, Сновський район, Чернігівська область, 15200-15203, Україна
# Болехів, Болехівська міська рада, Івано-Франківська область, 77200-77204, Україна
# Rieni, Bihor, 417415, România
# Томашпіль, Томашпільський район, Вінницька область, Україна
# Турійськ, Турійський район, Волинська область, Україна
# Амвросіївка, Амвросіївська міська рада, Амвросіївський район, Донецька область, 87300-87304, Україна
# Маневичі, Маневицький район, Волинська область, Україна
# Нові Санжари, Новосанжарський район, Полтавська область, 39300, Україна
# Тульчин, Тульчинський район, Вінницька область, Україна
# Валки, Валківський район, Харківська область, Україна
# Глухів, Глухівська міська рада, Сумська область, Україна
# Двуреченское сельское поселение, Пермский район, Пермский край, Приволжский федеральный округ, Россия
# Семенівка, Пустомитівський район, Львівська область, 81162, Україна
# Оржиця, Оржицький район, Полтавська область, 37702, Україна
# Пирятин, Пирятинський район, Полтавська область, Україна
# Ширяєве, Ширяївський район, Одеська область, 66800, Україна
# Володарск, Володарский район, Нижегородская область, Приволжский федеральный округ, Россия
# Мілове, Міловський район, Луганська область, 92500, Україна
# Апостолове, Апостолівський район, Дніпропетровська область, Україна
# Мостиська, Мостиська міська рада, Мостиський район, Львівська область, Україна
# Львів, Галицький район, Львівська міська рада, Львівська область, Україна
# Болград, Болградський район, Одеська область, 68700-68706, Україна
# П’ятихатки, П’ятихатський район, Дніпропетровська область, Україна
# Миколаївка, Слов’янський район, Донецька область, 83000-87999, Україна
# Городня, Городнянський район, Чернігівська область, 15100, Україна
# Нетішин, Хмельницька область, Україна
# Ічня, Ічнянський район, Чернігівська область, Україна
# Чутове, Чутівський район, Полтавська область, Україна
# Славутич, Славутицька міська рада, Київська область, Україна
# Новоархангельськ, Новоархангельський район, Кіровоградська область, 2640, Україна
# Старобільськ, Старобільський район, Луганська область, 92700, Україна
# Ружин, Ружинський район, Житомирська область, 13600, Україна
# Шишаки, Шишацький район, Полтавська область, 38000, Україна
# Путила, Путильський район, Чернівецька область, Україна
# Голованівськ, Голованівський район, Кіровоградська область, Україна
# Поліське, Рагівка, Поліський район, Київська область, 07033, Україна
# Шепетівка, Шепетівська міська рада, Хмельницька область, Україна
# Широке, Широківський район, Дніпропетровська область, 53700-53704, Україна
# Первомайський, Первомайська міська рада, Харківська область, 64100-64109, Україна
# Вижниця, Вижницький район, Чернівецька область, 59200, Україна
# Краснополье, Краснопольский район, Могилёвская область, Беларусь
# Піщанка, Піщанський район, Вінницька область, 24700, Україна
# Врадіївка, Врадіївський район, Миколаївська область, 56301, Україна
# Куликівка, Куликівський район, Чернігівська область, 16300, Україна
# Новоукраїнка, Новоукраїнський район, Кіровоградська область, 27100-27108, Україна
# Липовець, Липовецька міська рада, Липовецький район, Вінницька область, 22500-22505, Україна
# Охтирка, Охтирська міська об'єднана територіальна громада, Охтирська міська рада, Сумська область, Україна
# Лисянка, Лисянська селищна громада, Лисянський район, Черкаська область, 19300, Україна
# Баранівка, Баранівський район, Житомирська область, Україна
# Енергодар, Запорізька область, 71500, Україна
# Герца, Герцаївський район, Чернівецька область, Україна
# Кремінна, Кремінський район, Луганська область, Україна
# Іллінці, Іллінецький район, Вінницька область, Україна
# Черняхів, Черняхівський район, Житомирська область, Україна
# Мар’їнка, Мар’їнська міська рада, Мар’їнський район, Донецька область, 85600-85602, Україна
# Веселинове, Веселинівський район, Миколаївська область, Україна
# Знаменка, Орловский район, Орловская область, Центральный федеральный округ, БЕРЁЗОВАЯ УЛИЦА, Россия
# Березань, Київська область, 07540-07543, Україна
# Олександрівка, Олександрівська селищна рада, Олександрівський район, Донецька область, 84000-84004, Україна
# Долинська, Долинський район, Кіровоградська область, 28500, Україна
# Нікольське, Нікольська селищна рада, Нікольський район, Донецька область, 87000-87004, Україна
# Аэродром Щацк, «Урал», Чернослободское сельское поселение, Шацкий район, Рязанская область, Центральный федеральный округ, 391570, Россия
# Ржищів, Ржищівська міська рада, Київська область, 09230, Україна
# Ізюм, Ізюмська міська рада, Харківська область, Україна
# Токмак  ERROR
# Новгородка, Новгородківський район, Кіровоградська область, 28200, Україна
# Дружковка  ERROR
# Волноваха  ERROR
# Петрове  ERROR
# Новодністровськ, Чернівецька область, 60236, Україна
# Боровая  ERROR
# Середина-Буда, Середино-Будський район, Сумська область, Україна
# Віньківці, Віньковецький район, Хмельницька область, Україна
# Кодима, Кодимський район, Одеська область, Україна
# Підгайці, Підгаєцький район, Тернопільська область, 48000, Україна
# Заставна, Заставнівський район, Чернівецька область, Україна
# Трускавець, Трускавецька міська рада, Львівська область, 82200, Україна
# Кадіївка, Стахановська міська рада, Луганська область, Україна
# Гайворон, Гайворонський район, Кіровоградська область, 26300, Україна
# Ємільчине, Ємільчинський район, Житомирська область, Україна
# Киево, Троицкое сельское поселение, Шарьинский район, Костромская область, Центральный федеральный округ, Россия
# Чечельник, Чечельницький район, Вінницька область, 24800-24804, Україна
# Сватове, Сватівський район, Луганська область, Україна
# Берислав, Бериславський район, Херсонська область, 74300, Україна
# Богодухів, Богодухівський район, Харківська область, 62100-62109, Україна
# Корюківка, Корюківський район, Чернігівська область, 15300, Україна
# Новгород-Сіверський, Новгород-Сіверська міська рада, Чернігівська область, Україна
# Нововоронцовка, Нововоронцовський район, Херсонська область, 74200, Україна
# Срібне, Срібнянський район, Чернігівська область, Україна
# Сміла, Смілянська міська рада, Черкаська область, Україна
# Зачепилівка, Зачепилівський район, Харківська область, 64407, Україна
# Мала Виска, Маловисківський район, Кіровоградська область, 26200, Україна
# Вугледар, Вугледарська міська рада, Донецька область, 85670-85671, Україна
# Покровське, Покровський район, Дніпропетровська область, Україна
# Новоазовськ, Новоазовська міська рада, Новоазовський район, Донецька область, 87600-87605, Україна
# Чаплинка, Чаплинський район, Херсонська область, 75200, Україна
# Казанка, Казанківський район, Миколаївська область, 56000-56008, Україна
# Ланівці, Лановецький район, Тернопільська область, 47400, Україна
# Олевськ, Олевська міська об'єднана територіальна громада, Олевський район, Житомирська область, 11001-11002, Україна
# Воловець, Воловецький район, Закарпатська область, Україна
# Володарка, Володарський район, Київська область, 09300, Україна
# Бобринець, Бобринецький район, Кіровоградська область, Україна
# Овруч, Овруцька міська об'єднана територіальна громада, Овруцький район, Житомирська область, Україна
# Городенка, Городенківський район, Івано-Франківська область, 78100, Україна
# Світловодськ, Світловодська міська рада, Кіровоградська область, Україна
# Чернівці, Чернівецька область, 58000-58033, Україна
# Новомосковськ, Дніпропетровська область, 51200-51214, Україна
# Ківерці, Ківерцівський район, Волинська область, Україна
# Тисмениця, Тисменицький район, Івано-Франківська область, Україна
# Покровск, Хангаласский улус, Республика Саха (Якутия), Дальневосточный федеральный округ, 678000, Россия
# Іваничі, Іваничівський район, Волинська область, Україна
# Шевченкове, Котелевський район, Полтавська область, 38621, Україна
# Залізний Порт, Голопристанський район, Херсонська область, 75653, Україна
# Любашівка, Любашівський район, Одеська область, 66500-66502, Україна
# Тлумач, Тлумацький район, Івано-Франківська область, 78000-78004, Україна
# Корець, Корецький район, Рівненська область, Україна
# Ізяслав, Ізяславський район, Хмельницька область, Україна
# Торецьк, Торецька міська рада, Донецька область, 85200-85279, Україна
# Снігурівка, Снігурівська міська рада, Снігурівський район, Миколаївська область, 57309, Україна
# Маньківка, Маньківський район, Черкаська область, 20101, Україна
# Авдіївка, Авдіївська міська рада, Донецька область, 86060-86075, Україна
# Зіньків, Зіньківський район, Полтавська область, 38100, Україна
# Рогатин, Рогатинський район, Івано-Франківська область, Україна
# Селидове, Селидівська міська рада, Донецька область, 85400-85480, Україна
# Новий Буг, Новобузький район, Миколаївська область, 55600, Україна
# Сторожинець, Сторожинецький район, Чернівецька область, Україна
# Богородчани, Богородчанський район, Івано-Франківська область, Україна
# Новомиколаївка, Дружківська міська рада, Донецька область, 84297, Україна
# Кривий Ріг, Саксаганський район, Кривий Ріг, Дніпропетровська область, 50000-50479, Україна
# Близнюки, Близнюківський район, Харківська область, 64801, Україна
# Новомиргород, Новомиргородський район, Кіровоградська область, Україна
# Новоайдар, Новоайдарський район, Луганська область, 93505, Україна
# Ананьїв, Ананьївський район, Одеська область, 66400-66409, Україна
# Карлівка, Карлівський район, Полтавська область, Україна
# Оратів, Оратівський район, Вінницька область, Україна
# Попасна, Попаснянський район, Луганська область, Україна
# Короп, Коропський район, Чернігівська область, 16200, Україна
# Торез, Військово-цивільна адміністрація міста Торецьк, Донецька область, 86600-86690, Україна
# Білопілля, Білопільська міська об’єднана територіальна громада, Білопільський район, Сумська область, 41800-41810, Україна
# Новотроїцьке, Новотроїцька селищна рада, Волноваський район, Донецька область, 85732-85733, Україна
# Краснодон, Краснодонська міська рада, Луганська область, 94401-94408, Україна
# Доманівка, Доманівський район, Миколаївська область, 56400-56409, Україна
# Новий Розділ, Новороздільська міська рада, Львівська область, 81652, Україна
# Диканька, Диканський район, Полтавська область, 38500-38502, Україна
# Машівка, Машівський район, Полтавська область, Україна
# Костопіль, Костопільський район, Рівненська область, Україна
# Бахмач, Бахмацький район, Чернігівська область, Україна
# Путивль, Путивльська міська об'єднана територіальна громада, Путивльський район, Сумська область, Україна
# Барвінкове, Барвінківський район, Харківська область, 64700-64703, Україна
# Дрогобич, Дрогобицька міська рада, Львівська область, Україна
# Лохвиця, Лохвицький район, Полтавська область, 37200, Україна
# Білогір’я, Білогірський район, Хмельницька область, Україна
# Желтый, Ноҳияи Мурғоб, Вилояти Мухтори Кӯҳистони Бадахшон, Tajikistan
# Станично-Луганський район, Луганська область, Україна
# Демидівка, Демидівський район, Рівненська область, 35200, Україна
# Слов'яносербськ, Т-13-15, Лотикове, Слов’яносербський район, Луганська область, 93747, Україна
# Володимирець, Володимирецький район, Рівненська область, 34300, Україна
# Екатеринбург, городской округ Екатеринбург, Свердловская область, Уральский федеральный округ, Россия
# Стара Синява, Старосинявський район, Хмельницька область, 31400, Україна
# Старобешеве, Старобешівська селищна рада, Старобешівський район, Донецька область, 87200-87205, Україна
# Вараш, Рівненська область, 34400, Україна
# Тернівка, Тернівська міська рада, Дніпропетровська область, 51500-51509, Україна
# Єланець, Єланецький район, Миколаївська область, 55507, Україна
# Бровари, Київська область, 07400, Україна
# Ратне, Ратнівський район, Волинська область, 44100, Україна
# Глубокая, Анадырский район, Чукотский автономный округ, Дальневосточный федеральный округ, Россия
# Шумське, Москалівка, Роменський район, Сумська область, 42062, Україна
# Любар, Любарський район, Житомирська область, 13100-13104, Україна
# Калинівка, Калинівський район, Вінницька область, Україна
# Високопілля, Високопільський район, Херсонська область, Україна
# Хмільник, Вінницька область, 22000, Україна
# Сахновщина, Сахновщинський район, Харківська область, 64501, Україна
# Краснянский посёлковый совет, Слободзейский район, Unitățile administrativ-teritoriale din stînga Nistrului, Нистрения / Приднестровье / Придністров'я, 5706, Moldova
# Тячів, Тячівський район, Закарпатська область, 90500, Україна
# Вільшани, Дергачівський район, Харківська область, 62360, Україна
# Перевальськ, Перевальський район, Луганська область, Україна
# Лутугине, Лутугинський район, Луганська область, 92000, Україна
# Арбузинка, Арбузинський район, Миколаївська область, 55300, Україна
# Лугини, Лугинська селищна об'єднана територіальна громада, Лугинський район, Житомирська область, 11300, Україна
# Березнегувате, Березнегуватський район, Миколаївська область, 56203, Україна
# Ржев, городской округ Ржев, Тверская область, Центральный федеральный округ, 172340, Россия
# Рівне, Рівненська область, 33000-33499, Україна
# Любешів, Любешівський район, Волинська область, 44200-44205, Україна
# Михайлівка, Дунаєвецький район, Хмельницька область, 32434, Україна
# Горностаївка, Горностаївський район, Херсонська область, 74602, Україна
# Катеринопіль, Катеринопільський район, Черкаська область, 20500, Україна
# Чернігівка, Чернігівський район, Запорізька область, Україна
# Компаніївка, Компаніївський район, Кіровоградська область, 28402, Україна
# Підволочиськ, Підволочиський район, Тернопільська область, 47800, Україна
# Недригайлів, Недригайлівська селищна об’єднана територіальна громада, Недригайлівський район, Сумська область, 42100, Україна
# Драгобрат, Рахівський район, Закарпатська область, Україна
# Сосновка, Вятскополянский район, Кировская область, Приволжский федеральный округ, Россия
# Захарівка, Захарівський район, Одеська область, Україна
# Братское, Надтеречный район, Северо-Кавказский федеральный округ, Россия
# Балта, Одеська область, 66100-66105, Україна
# Слов’яносербськ, Слов’яносербський район, Луганська область, 93701, Україна
# Талалаївка, Талалаївський район, Чернігівська область, 17200, Україна
# Сосница, Полоцкий район, Витебская область, Беларусь
# Пустомити, Пустомитівська міська рада, Пустомитівський район, Львівська область, 81100, Україна
# Кіцмань, Кіцманський район, Чернівецька область, Україна
# Козельщина, Козельщинський район, Полтавська область, 39100-39104, Україна
# Петропавлівка, Станично-Луганський район, Луганська область, 93613, Україна
# Вільногірськ, Дніпропетровська область, 51700-51799, Україна
# Летичів, Летичівський район, Хмельницька область, 31500, Україна
# Весело-Вознесенка, Неклиновский район, Ростовская область, Южный федеральный округ, 346861, Россия
# Зарічне, Зарічненський район, Рівненська область, 34000, Україна
# Kám, Vasvári járás, Vas megye, Nyugat-Dunántúl, Dunántúl, 9841, Magyarország
# Варва, Варвинський район, Чернігівська область, Україна
# Кривий, Хустський район, Закарпатська область, 90415, Україна
# Буринь, Буринська міська об’єднана територіальна громада, Буринський район, Сумська область, Україна
# Здолбунів, Здолбунівський район, Рівненська область, Україна
# Васильків, Київська область, 08600-08606, Україна
# Гнівань, Тиврівський район, Вінницька область, Україна
# Іршава, Іршавський район, Закарпатська область, 90100, Україна
# Добровеличківка, Добровеличківський район, Кіровоградська область, 27000-27005, Україна
# им. Белова, Псковский район, Псковская область, Северо-Западный федеральный округ, Россия
# Радомишль, Радомишльська міська рада, Радомишльська міська об’єднана територіальна громада, Радомишльський район, Житомирська область, Україна
# Лановці  ERROR
# Крижопіль, Крижопільський район, Вінницька область, 24601, Україна
# Виноградів, Виноградівський район, Закарпатська область, 90300, Україна
# Розовка, Дзержинский район, Минская область, 222740, Беларусь
# Нова Ушиця, Новоушицький район, Хмельницька область, 32600, Україна
# Коломак, Коломацький район, Харківська область, 63108, Україна
# Радивилів, Радивилівський район, Рівненська область, 35500-35508, Україна
# Тарутине, Тарутинський район, Одеська область, 68502, Україна
# Локачі, Локачинський район, Волинська область, 45500, Україна
# Марківка, Марківський район, Луганська область, 92405, Україна
# Кіровське, Кіровська мiська рада, Донецька область, 86300-86390, Україна
# Нижний Новгород, городской округ Нижний Новгород, Нижегородская область, Приволжский федеральный округ, Россия
# Рахів, Рахівський район, Закарпатська область, 90600, Україна
# Білозерка, Білозерський район, Херсонська область, Україна
# Мирноград, Мирноградська міська рада, Донецька область, 85320-85329, Україна

# %%
clean_reg = dict() # Dict to store region name in ukrainian language
clean_city = dict() # Dict to store city name in ukrainian language

for city in regions.keys():
    # Kyiv considered as a separate region
    if city == 'Киев':
        clean_reg[city] = 'Київ'
        clean_city[city] = 'Київ'    
    
    elif 'Україна' in regions[city]:
        temp = regions[city].split(',')
        c = temp[0]
        temp = [i.strip() for i in temp if 'область' in i]
        if temp:
            region = temp[0]
            clean_reg[city] = region
            clean_city[city] = c
            
df['region'] = df['city']
df['region'] = df['region'].replace(clean_reg)

df.drop(df.loc[df['city'] == df['region'], 'city'].index, inplace = True)
df['city'] = df['city'].replace(clean_city)

# %%
# Transliteration
df['city'] = df['city'].apply(lambda x: translitua.translit(x))
df['region'] = df['region'].apply(lambda x: translitua.translit(x))
df['region'] = df['region'].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#   price_usd                parse3 offer_type        type       city     region
# 0  71 970 $     1 комната 57 м кв       sell  apartments       Kyiv       Kyiv
# 1  68 000 $     1 комната 68 м кв       sell  apartments       Kyiv       Kyiv
# 2  53 000 $      134 м кв 7 соток       sell       house  Vinnytsia  Vinnytska
# 3  36 500 $     1 комната 36 м кв       sell  apartments  Vinnytsia  Vinnytska
# 4  16 582 $  1 комната 40.24 м кв       sell  apartments  Vinnytsia  Vinnytska

# %% [markdown]
# ### "parse3" column preprocessing

# %%
# Extracting number of rooms, living area and area of land
def rooms(x, mode):
    if mode == 'rooms':
        t = re.search(r'\d+\s\bком', x)
    elif mode == 'area':
        t = re.search(r'\d+\s\bм\s\bкв', x)
        if not t:
            t = re.search(r'\d+\s\bкв\.\s\bм', x)
    elif mode == 'land_area':
        t = re.search(r'\d+\s\bсот', x)
        
    if t:
        return re.findall(r'\d+', t[0])[0]
    else:
        return np.nan

def remove_dot(x):
    try:
        t = re.findall(r'\.\d+', x)
    except:
        return ''
    if t:
        x = x.replace(t[0], '')
        return x
    else:
        return x

df['parse3'] = df['parse3'].apply(remove_dot)
    
df['rooms'] = df['parse3'].apply(lambda x: rooms(x, mode = 'rooms'))
df['area'] = df['parse3'].apply(lambda x: rooms(x, mode = 'area'))
df['land_area'] = df['parse3'].apply(lambda x: rooms(x, mode = 'land_area'))

df.drop('parse3', axis = 1, inplace = True)

# %%
# Data after "parse3" column preprocessing
df.head()
# Out:
#   price_usd offer_type        type       city     region rooms area land_area
# 0  71 970 $       sell  apartments       Kyiv       Kyiv     1   57       NaN
# 1  68 000 $       sell  apartments       Kyiv       Kyiv     1   68       NaN
# 2  53 000 $       sell       house  Vinnytsia  Vinnytska   NaN  134         7
# 3  36 500 $       sell  apartments  Vinnytsia  Vinnytska     1   36       NaN
# 4  16 582 $       sell  apartments  Vinnytsia  Vinnytska     1   40       NaN

# %% [markdown]
# ### Price preprocessing

# %%
df['price_hr'] = df[df['price_usd'].str.contains('грн')]['price_usd']
df.loc[df['price_usd'].str.contains('грн'), 'price_usd'] = 0

# %%
df.head()
# Out:
#   price_usd offer_type        type       city     region rooms area land_area  \
# 0  71 970 $       sell  apartments       Kyiv       Kyiv     1   57       NaN
# 1  68 000 $       sell  apartments       Kyiv       Kyiv     1   68       NaN
# 2  53 000 $       sell       house  Vinnytsia  Vinnytska   NaN  134         7
# 3  36 500 $       sell  apartments  Vinnytsia  Vinnytska     1   36       NaN
# 4  16 582 $       sell  apartments  Vinnytsia  Vinnytska     1   40       NaN
#
#   price_hr
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
def muney(x):
    if x:
        x = str(x).replace(' ', '')
        x = re.findall(r'\d+', x)
        if x:
            return int(x[0])
        else:
            return 0
    else:
        return 0

df['price_usd'] = df['price_usd'].apply(muney)
df['price_hr'] = df['price_hr'].apply(muney)

hr_to_usd = 0.041

# %%
df['price_usd'] = df['price_usd'].astype('int')
df['price_hr'] = df['price_hr'].astype('int')

df_hr = df[df['price_hr'] > 0]
hr_index = df_hr.index

df.loc[hr_index, 'price_usd'] = df_hr['price_hr'] * hr_to_usd

df.drop('price_hr', axis = 1, inplace = True)

# %%
# Data after price preprocessing
df.head()
# Out:
#    price_usd offer_type        type       city     region rooms area land_area
# 0    71970.0       sell  apartments       Kyiv       Kyiv     1   57       NaN
# 1    68000.0       sell  apartments       Kyiv       Kyiv     1   68       NaN
# 2    53000.0       sell       house  Vinnytsia  Vinnytska   NaN  134         7
# 3    36500.0       sell  apartments  Vinnytsia  Vinnytska     1   36       NaN
# 4    16582.0       sell  apartments  Vinnytsia  Vinnytska     1   40       NaN

# %% [markdown]
# ### Calculating price for square meter and price for 1/100 of hectar

# %%
df[['rooms', 'area', 'land_area']] = df[['rooms', 'area', 'land_area']].astype('float')
df['price_sqm'] = df['price_usd'] / df['area']
df['price_hndr'] = df['price_usd'] / df['land_area']

df[['price_sqm', 'price_hndr']] = df[['price_sqm', 'price_hndr']].round(2)

# %%
df.head()
# Out:
#    price_usd offer_type        type       city     region  rooms   area  \
# 0    71970.0       sell  apartments       Kyiv       Kyiv    1.0   57.0
# 1    68000.0       sell  apartments       Kyiv       Kyiv    1.0   68.0
# 2    53000.0       sell       house  Vinnytsia  Vinnytska    NaN  134.0
# 3    36500.0       sell  apartments  Vinnytsia  Vinnytska    1.0   36.0
# 4    16582.0       sell  apartments  Vinnytsia  Vinnytska    1.0   40.0
#
#    land_area  price_sqm  price_hndr
# 0        NaN    1262.63         NaN
# 1        NaN    1000.00         NaN
# 2        7.0     395.52     7571.43
# 3        NaN    1013.89         NaN
# 4        NaN     414.55         NaN

# %%
# Saving preprocessed data to csv file
df.to_csv('ria_ready.csv', index = False)
